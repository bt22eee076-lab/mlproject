# %% [markdown]
# <a href="https://colab.research.google.com/github/bt22eee076-lab/mlproject/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle -q

# %%
import os
import json
import zipfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity
from wordcloud import WordCloud
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# !pip install kagglehub

# %%
import kagglehub
kagglehub.login()  # Paste your copied token when prompted!
# Out:
# ...
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
kagglehub
# Out:
# <module 'kagglehub' from '/usr/local/lib/python3.12/dist-packages/kagglehub/__init__.py'>

# %%
path = kagglehub.dataset_download("notshrirang/spotify-million-song-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 20.7M/20.7M [00:02<00:00, 9.98MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/notshrirang/spotify-million-song-dataset/versions/1

# %%
# !ls
# Out:
# sample_data

# %%
print(f"Listing contents of the downloaded dataset directory: {path}")
# !ls {path}
# Out:
# Listing contents of the downloaded dataset directory: /root/.cache/kagglehub/datasets/notshrirang/spotify-million-song-dataset/versions/1
# spotify_millsongdata.csv

# %%
# Move the dataset file to the current working directory
# !mv {path}/spotify_millsongdata.csv .

print("Dataset moved to current working directory.")
# !ls
# Out:
# Dataset moved to current working directory.
# sample_data  spotify_millsongdata.csv

# %%
# The dataset `spotify_millsongdata.csv` has already been extracted and moved to the current directory.
# This cell is no longer needed.
# You can now directly work with 'spotify_millsongdata.csv'.

# %%
df=pd.read_csv("spotify_millsongdata.csv")
df.head()
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57650 entries, 0 to 57649
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  57650 non-null  object
#  1   song    57650 non-null  object
#  2   link    57650 non-null  object
#  3   text    57650 non-null  object
# dtypes: object(4)
# memory usage: 1.8+ MB

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
top_artists=df['artist'].value_counts().head(10)
print('\n top 10 artists')
print(top_artists)
# Out:
#  top 10 artists
# artist
# Donna Summer        191
# Gordon Lightfoot    189
# Bob Dylan           188
# George Strait       188
# Loretta Lynn        187
# Alabama             187
# Cher                187
# Reba Mcentire       187
# Chaka Khan          186
# Dean Martin         186
# Name: count, dtype: int64

# %%
df=df.sample(10000)
df=df.drop('link',axis=1).reset_index(drop=True)

# %%
all_lyrics=" ".join(df['text'].dropna())
wordcloud=WordCloud(height=400,width=800,background_color='white').generate(all_lyrics)

# %%
plt.figure(figsize=(10,5))
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.title("most common words in lyrics")
plt.show()

# %% [markdown]
# data preprocessing

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words=set(stopwords.words('english'))
#

# %%
def preprocess_text(text):
  text=re.sub(r"[^a-zA-z\s]","",text)
  text=text.lower()
  tokens=word_tokenize(text)
  tokens=[word for word in tokens if word not in stop_words]
  return " ".join(tokens)

# %%
df['cleaned_text']=df['text'].apply(preprocess_text)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer=TfidfVectorizer(max_features=5000)
tfidf_matrix=tfidf_vectorizer.fit_transform(df['cleaned_text'])

# %%
cosine_sim=cosine_similarity(tfidf_matrix,tfidf_matrix)

# %%
def recommend_songs(song_name,cosine_sim=cosine_sim,df=df,top_n=5):
  idx=df[df['song'].str.lower()==song_name.lower()].index
  if len(idx)==0:
    return "song not found"
  idx=idx[0]
  sim_scores=list(enumerate(cosine_sim[idx]))
  sim_scores=sorted(sim_scores,key=lambda x:x[1],reverse=True)
  sim_scores=sim_scores[1:top_n+1]
  song_indices=[i[0] for i in sim_scores]
  return df[['artist','song']].iloc[song_indices]

# %%
df["song"][2]
# Out:
# 'Happy Holidays'

# %%
print("\n\nrecomended songs")
recomendations=recommend_songs('Happy Holidays')
print(recomendations)
# Out:
# recomended songs
#              artist                                song
# 711            Rush             Force Ten (Phoenix, AZ)
# 3507  Stevie Wonder                        Silver Bells
# 706    Kenny Rogers                        Silver Bells
# 2751   Mariah Carey  Christmas Time Is In The Air Again
# 1227        'n Sync                In Love On Christmas
